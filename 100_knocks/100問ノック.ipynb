# %% [markdown]
# <a href="https://colab.research.google.com/github/mikzk/python-learning-record/blob/main/100_knocks/100%E5%95%8F%E3%83%8E%E3%83%83%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
print("Hello,World!")
# Out:
# Hello,World!

# %%
#2

print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
#3

print(1,2,3,"Hello")
# Out:
# 1 2 3 Hello

# %%
#4

print(1)
#print(2)
print(3)
# Out:
# 1
# 3

# %%
#5コラボラトリでは、セルの最後に書かれているデータの中身を、自動的に画面に表示する

"""
print(1)
print(2)
print(3)
"""
# Out:
# '\nprint(1)\nprint(2)\nprint(3)\n'

# %%
#6

x=10
print(x)
# Out:
# 10

# %%
#7

x=1+2
print(x)
# Out:
# 3

# %%
#8

x="1"+"2"
print(x)
# Out:
# 12

# %%
#9

print(str(10))
print(int("10"))
# Out:
# 10
# 10

# %%
#10

print("1\n2\n3")


# エスケープシーケンスの出力例
print("キャリッジリターン: Hello\rWorld")  # \r → 行頭に戻る
print("改行: Hello\nWorld")  # \n → 改行
print("タブ: Hello\tWorld")  # \t → タブ
print("バックスペース: Hello\bWorld")  # \b → 1文字削除
print("フォームフィード: Hello\fWorld")  # \f → 一部の環境でページ送り
print("垂直タブ: Hello\vWorld")  # \v → 垂直タブ（環境によって表示が異なる）
print("バックスラッシュ: C:\\test")  # \\ → バックスラッシュそのまま表示
print("シングルクォート: It\'s Python")  # \' → シングルクォート
print("ダブルクォート: She said \"Hello\"")  # \" → ダブルクォート
print("16進数コード: \x41\x42\x43")  # \xhh → A B C
print("8進数コード: \101")  # \101 は 'A'（8進数）
print("Unicode: \u03A9")  # \uXXXX → Ω（ギリシャ文字オメガ）
print("Unicode絵文字: \U0001F600")  # \UXXXXXXXX → スマイル絵文字
# Out:
# 1
# 2
# 3
# World
# 改行: Hello
# World
# タブ: Hello	World
# World
# フォームフィード: HelloWorld
# 垂直タブ: HelloWorld
# バックスラッシュ: C:\test
# シングルクォート: It's Python
# ダブルクォート: She said "Hello"
# 16進数コード: ABC
# 8進数コード: A
# Unicode: Ω
# Unicode絵文字: 😀

# %%
#回答例のようにエスケープシーケンス \\ を使用することで、文字列内に \ を文字として含めることができます。このように、エスケープシーケンを通常の文字として扱うための操作を エスケープ と呼びます。

print("C:\\test")
# Out:
# C:\test

# %%
#12

print(r"C:\test")
# Out:
# C:\test

# %%
#13

name="Python"
print(f'Hello, {name}!')
# Out:
# Hello, Python!

# %%
#14
x=len("pyhton")
print(x)
# Out:
# 6

# %%
#15
x='python'
print(x[0:2])
# Out:
# py

# %%
#16
x=None
print(x)
# Out:
# None

# %%
#17
a = 10
b = 3.14
c = "Hello, Python!"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
lst = [1, 2, 3]
print(lst)
print(lst[0])
# Out:
# [1, 2, 3]
# 1

# %%
#19
lst = [1, 2, 3]
print(lst[0:2])
# Out:
# [1, 2]

# %%
#20
lst = [1, 2, 3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
#21
lst=[1,2,3]
print(len(lst))
# Out:
# 3

# %%
#22
lst=[1,2,3]
lst.remove(2)
print(lst)
# Out:
# [1, 3]

# %%
#23
x=[1,2]
y=[3,4]
lst=x+y
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
#24
x=15
if x>10:
  print( "xは10より大きい" )
# Out:
# xは10より大きい

# %%
#25
x=10

if x>10:
  print( "xは10より大きい" )
elif x>5:
  print("xは5より大きいが、10以下")
else :
  print("xは5以下")
# Out:
# xは5より大きいが、10以下
